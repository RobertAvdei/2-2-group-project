# %%
import os
import torch.backends.cudnn as cudnn
import yaml
from train import train
from utils import AttrDict
import pandas as pd

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
cudnn.benchmark = True
cudnn.deterministic = False

# %%
def get_config(file_path):
    with open(file_path, 'r', encoding="utf8") as stream:
        opt = yaml.safe_load(stream)
    opt = AttrDict(opt)
    if opt.lang_char == 'None':
        characters = ''
        for data in opt['select_data'].split('-'):
            csv_path = os.path.join(opt['train_data'], data, 'labels.csv')
            df = pd.read_csv(csv_path, sep='^([^,]+),', engine='python', usecols=['filename', 'words'], keep_default_na=False)
            all_char = ''.join(df['words'])
            characters += ''.join(set(all_char))
        characters = sorted(set(characters))
        opt.character= ''.join(characters)
    else:
        opt.character = opt.number + opt.symbol + opt.lang_char
    os.makedirs(f'./saved_models/{opt.experiment_name}', exist_ok=True)
    return opt

# %%
opt = get_config("config_files/en_filtered_config.yaml")
train(opt, amp=False)
# Out:
# Filtering the images containing characters which are not in opt.character
# Filtering the images whose label is longer than opt.batch_max_length
# --------------------------------------------------------------------------------
# dataset_root: all_data\train
# opt.select_data: ['all_data\\train']
# opt.batch_ratio: ['1']
# --------------------------------------------------------------------------------
# dataset_root:    all_data\train	 dataset: all_data\train
# all_data\train/
# sub-directory:	/.	 num samples: 32000
# num total samples of all_data\train: 32000 x 1.0 (total_data_usage_ratio) = 32000
# num samples of all_data\train per batch: 32 x 1.0 (batch_ratio) = 32
# --------------------------------------------------------------------------------
# Total_batch_size: 32 = 32
# --------------------------------------------------------------------------------
# dataset_root:    all_data\val	 dataset: /
# all_data\val/
# sub-directory:	/.	 num samples: 8000
# --------------------------------------------------------------------------------
# No Transformation module specified
# model input parameters 32 124 20 1 256 256 97 32 None VGG BiLSTM CTC
# loading pretrained model from saved_models/en_filtered/best_accuracy.pth
# Model:
# DataParallel(
#   (module): Model(
#     (FeatureExtraction): VGG_FeatureExtractor(
#       (ConvNet): Sequential(
#         (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#         (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): ReLU(inplace=True)
#         (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (6): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (7): ReLU(inplace=True)
#         (8): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (9): ReLU(inplace=True)
#         (10): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#         (11): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (12): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (13): ReLU(inplace=True)
#         (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (16): ReLU(inplace=True)
#         (17): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#         (18): Conv2d(256, 256, kernel_size=(2, 2), stride=(1, 1))
#         (19): ReLU(inplace=True)
#       )
#     )
#     (AdaptiveAvgPool): AdaptiveAvgPool2d(output_size=(None, 1))
#     (SequenceModeling): Sequential(
#       (0): BidirectionalLSTM(
#         (rnn): LSTM(256, 256, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=512, out_features=256, bias=True)
#       )
#       (1): BidirectionalLSTM(
#         (rnn): LSTM(256, 256, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=512, out_features=256, bias=True)
#       )
#     )
#     (Prediction): Linear(in_features=256, out_features=97, bias=True)
#   )
# )
# Modules, Parameters
# module.FeatureExtraction.ConvNet.0.weight 288
# module.FeatureExtraction.ConvNet.0.bias 32
# module.FeatureExtraction.ConvNet.3.weight 18432
# module.FeatureExtraction.ConvNet.3.bias 64
# module.FeatureExtraction.ConvNet.6.weight 73728
# module.FeatureExtraction.ConvNet.6.bias 128
# module.FeatureExtraction.ConvNet.8.weight 147456
# module.FeatureExtraction.ConvNet.8.bias 128
# module.FeatureExtraction.ConvNet.11.weight 294912
# module.FeatureExtraction.ConvNet.12.weight 256
# module.FeatureExtraction.ConvNet.12.bias 256
# module.FeatureExtraction.ConvNet.14.weight 589824
# module.FeatureExtraction.ConvNet.15.weight 256
# module.FeatureExtraction.ConvNet.15.bias 256
# module.FeatureExtraction.ConvNet.18.weight 262144
# module.FeatureExtraction.ConvNet.18.bias 256
# module.SequenceModeling.0.rnn.weight_ih_l0 262144
# module.SequenceModeling.0.rnn.weight_hh_l0 262144
# module.SequenceModeling.0.rnn.bias_ih_l0 1024
# module.SequenceModeling.0.rnn.bias_hh_l0 1024
# module.SequenceModeling.0.rnn.weight_ih_l0_reverse 262144
# module.SequenceModeling.0.rnn.weight_hh_l0_reverse 262144
# module.SequenceModeling.0.rnn.bias_ih_l0_reverse 1024
# module.SequenceModeling.0.rnn.bias_hh_l0_reverse 1024
# module.SequenceModeling.0.linear.weight 131072
# module.SequenceModeling.0.linear.bias 256
# module.SequenceModeling.1.rnn.weight_ih_l0 262144
# module.SequenceModeling.1.rnn.weight_hh_l0 262144
# module.SequenceModeling.1.rnn.bias_ih_l0 1024
# module.SequenceModeling.1.rnn.bias_hh_l0 1024
# module.SequenceModeling.1.rnn.weight_ih_l0_reverse 262144
# module.SequenceModeling.1.rnn.weight_hh_l0_reverse 262144
# module.SequenceModeling.1.rnn.bias_ih_l0_reverse 1024
# module.SequenceModeling.1.rnn.bias_hh_l0_reverse 1024
# module.SequenceModeling.1.linear.weight 131072
# module.SequenceModeling.1.linear.bias 256
# module.Prediction.weight 24832
# module.Prediction.bias 97
# Total Trainable Params: 3781345
# Trainable params num :  3781345
# Optimizer:
# Adadelta (
# Parameter Group 0
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     lr: 0.1
#     maximize: False
#     rho: 0.95
#     weight_decay: 0
# )
# ------------ Options -------------
# number: 0123456789
# symbol: !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~ €
# lang_char: ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
# experiment_name: en_filtered
# train_data: all_data\train
# valid_data: all_data\val
# manualSeed: 1111
# workers: 2
# batch_size: 32
# num_iter: 2000
# valInterval: 50
# saved_model: saved_models/en_filtered/best_accuracy.pth
# FT: False
# optim: False
# lr: 0.1
# beta1: 0.9
# rho: 0.95
# eps: 1e-08
# grad_clip: 5
# select_data: ['all_data\\train']
# batch_ratio: ['1']
# total_data_usage_ratio: 1.0
# batch_max_length: 32
# imgH: 32
# imgW: 124
# rgb: False
# contrast_adjust: 0.0
# sensitive: True
# PAD: True
# data_filtering_off: False
# Transformation: None
# FeatureExtraction: VGG
# SequenceModeling: BiLSTM
# Prediction: CTC
# num_fiducial: 20
# input_channel: 1
# output_channel: 256
# hidden_size: 256
# decode: greedy
# new_prediction: False
# freeze_FeatureFxtraction: False
# freeze_SequenceModeling: False
# character: 0123456789!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~ €ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
# num_class: 97
# ---------------------------------------
# c:\Users\julia\Documents\School\EasyOCR Custom model\EasyOCR-master\trainer\train.py:172: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# training time:  0.8021624088287354
# [50/2000] Train loss: 0.22958, Valid loss: 0.26667, Elapsed_time: 0.80216
# Current_accuracy : 65.200, Current_norm_ED  : 0.9280
# Best_accuracy    : 65.200, Best_norm_ED     : 0.9280
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Dabih                     | Dabih                     | 0.2553	True
# clodpated                 | clodpated                 | 0.5554	True
# --------------------------------------------------------------------------------
# validation time:  22.835825443267822
# training time:  0.6893954277038574
# [100/2000] Train loss: 0.21153, Valid loss: 0.27070, Elapsed_time: 24.32738
# Current_accuracy : 63.475, Current_norm_ED  : 0.9214
# Best_accuracy    : 65.200, Best_norm_ED     : 0.9280
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# knavishness               | knavishness               | 0.2900	True
# trabecular                | trabecular                | 0.4100	True
# --------------------------------------------------------------------------------
# validation time:  22.031795263290405
# training time:  0.7402904033660889
# [150/2000] Train loss: 0.20565, Valid loss: 0.26405, Elapsed_time: 47.09947
# Current_accuracy : 66.938, Current_norm_ED  : 0.9285
# Best_accuracy    : 66.938, Best_norm_ED     : 0.9285
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# clear-walled              | clear-walled              | 0.3276	True
# tasseller                 | tasseler                  | 0.0509	False
# --------------------------------------------------------------------------------
# validation time:  22.222904920578003
# training time:  0.6122057437896729
# [200/2000] Train loss: 0.20221, Valid loss: 0.24505, Elapsed_time: 69.93458
# Current_accuracy : 67.775, Current_norm_ED  : 0.9324
# Best_accuracy    : 67.775, Best_norm_ED     : 0.9324
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# huyghenian                | huyghenian                | 0.5345	True
# microfilming              | microfilming              | 0.1254	True
# --------------------------------------------------------------------------------
# validation time:  22.26124143600464
# training time:  0.7108163833618164
# [250/2000] Train loss: 0.20885, Valid loss: 0.25707, Elapsed_time: 92.90664
# Current_accuracy : 67.075, Current_norm_ED  : 0.9329
# Best_accuracy    : 67.775, Best_norm_ED     : 0.9329
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Scoville                  | Scoville                  | 0.0453	True
# peropus                   | peronus                   | 0.0629	False
# --------------------------------------------------------------------------------
# validation time:  22.37462067604065
# training time:  0.6423776149749756
# [300/2000] Train loss: 0.20856, Valid loss: 0.23081, Elapsed_time: 115.92364
# Current_accuracy : 69.938, Current_norm_ED  : 0.9384
# Best_accuracy    : 69.938, Best_norm_ED     : 0.9384
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# escalating                | escalating                | 0.3581	True
# derv                      | derv                      | 0.2338	True
# --------------------------------------------------------------------------------
# validation time:  22.442011833190918
# training time:  0.7258338928222656
# [350/2000] Train loss: 0.18968, Valid loss: 0.24525, Elapsed_time: 139.09148
# Current_accuracy : 68.250, Current_norm_ED  : 0.9331
# Best_accuracy    : 69.938, Best_norm_ED     : 0.9384
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# redeemeress               | redeemeress               | 0.7860	True
# Mauler                    | Mauler                    | 0.5763	True
# --------------------------------------------------------------------------------
# validation time:  22.244404077529907
# training time:  0.7346625328063965
# [400/2000] Train loss: 0.20838, Valid loss: 0.22709, Elapsed_time: 162.07055
# Current_accuracy : 70.562, Current_norm_ED  : 0.9392
# Best_accuracy    : 70.562, Best_norm_ED     : 0.9392
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Lynnell                   | Lynnell                   | 0.1701	True
# bennettitaceous           | bennetitaceous            | 0.3168	False
# --------------------------------------------------------------------------------
# validation time:  22.25544309616089
# training time:  0.7393307685852051
# [450/2000] Train loss: 0.18445, Valid loss: 0.23456, Elapsed_time: 185.06532
# Current_accuracy : 69.100, Current_norm_ED  : 0.9367
# Best_accuracy    : 70.562, Best_norm_ED     : 0.9392
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# laparotomist              | laparotomist              | 0.2963	True
# unessentialness           | unessentialness           | 0.1522	True
# --------------------------------------------------------------------------------
# validation time:  22.395310163497925
# training time:  0.64040207862854
# [500/2000] Train loss: 0.18831, Valid loss: 0.23712, Elapsed_time: 208.10103
# Current_accuracy : 67.912, Current_norm_ED  : 0.9338
# Best_accuracy    : 70.562, Best_norm_ED     : 0.9392
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# opthalmoplegy             | opthalmoplegy             | 0.1059	True
# bethankit                 | beloale                   | 0.0009	False
# --------------------------------------------------------------------------------
# validation time:  22.294218063354492
# training time:  0.6807551383972168
# [550/2000] Train loss: 0.19425, Valid loss: 0.22355, Elapsed_time: 231.07701
# Current_accuracy : 70.337, Current_norm_ED  : 0.9389
# Best_accuracy    : 70.562, Best_norm_ED     : 0.9392
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Hemithea                  | Hemitea                   | 0.1081	False
# laurotetanine             | bunretetanuins            | 0.0001	False
# --------------------------------------------------------------------------------
# validation time:  22.16260528564453
# training time:  0.6411468982696533
# [600/2000] Train loss: 0.17640, Valid loss: 0.22839, Elapsed_time: 253.88076
# Current_accuracy : 69.625, Current_norm_ED  : 0.9367
# Best_accuracy    : 70.562, Best_norm_ED     : 0.9392
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# vesp                      | vesp                      | 0.8538	True
# hempseed                  | hempseed                  | 0.6517	True
# --------------------------------------------------------------------------------
# validation time:  22.4117910861969
# training time:  0.7488300800323486
# [650/2000] Train loss: 0.17526, Valid loss: 0.21231, Elapsed_time: 277.04138
# Current_accuracy : 71.537, Current_norm_ED  : 0.9418
# Best_accuracy    : 71.537, Best_norm_ED     : 0.9418
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# hyperbrachyskelic         | hypertrachyselic          | 0.0339	False
# asexualise                | asexualise                | 0.4437	True
# --------------------------------------------------------------------------------
# validation time:  22.28642773628235
# training time:  0.7137272357940674
# [700/2000] Train loss: 0.15583, Valid loss: 0.20692, Elapsed_time: 300.04154
# Current_accuracy : 72.025, Current_norm_ED  : 0.9434
# Best_accuracy    : 72.025, Best_norm_ED     : 0.9434
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# pentrit                   | pentrit                   | 0.5593	True
# Forkland                  | Forkland                  | 0.2356	True
# --------------------------------------------------------------------------------
# validation time:  22.3882098197937
# training time:  0.6373648643493652
# [750/2000] Train loss: 0.17025, Valid loss: 0.22636, Elapsed_time: 323.06711
# Current_accuracy : 71.275, Current_norm_ED  : 0.9390
# Best_accuracy    : 72.025, Best_norm_ED     : 0.9434
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# unsliced                  | unsliced                  | 0.1081	True
# half-submerged            | half-submerged            | 0.0326	True
# --------------------------------------------------------------------------------
# validation time:  22.31401562690735
# training time:  0.6700053215026855
# [800/2000] Train loss: 0.17372, Valid loss: 0.22809, Elapsed_time: 346.05113
# Current_accuracy : 68.650, Current_norm_ED  : 0.9373
# Best_accuracy    : 72.025, Best_norm_ED     : 0.9434
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# snootiness                | snootiness                | 0.6421	True
# nitromersol               | nitromerscl               | 0.0104	False
# --------------------------------------------------------------------------------
# validation time:  22.25556755065918
# training time:  0.7132630348205566
# [850/2000] Train loss: 0.17988, Valid loss: 0.22289, Elapsed_time: 369.01996
# Current_accuracy : 70.675, Current_norm_ED  : 0.9413
# Best_accuracy    : 72.025, Best_norm_ED     : 0.9434
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# crooning                  | crooring                  | 0.4634	False
# Kentiga                   | so-ltigp                  | 0.0008	False
# --------------------------------------------------------------------------------
# validation time:  22.33707547187805
# training time:  0.6768124103546143
# [900/2000] Train loss: 0.16740, Valid loss: 0.21039, Elapsed_time: 392.03385
# Current_accuracy : 71.325, Current_norm_ED  : 0.9433
# Best_accuracy    : 72.025, Best_norm_ED     : 0.9434
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# maistres                  | maistres                  | 0.2921	True
# nutcrackers               | nutcrackers               | 0.5721	True
# --------------------------------------------------------------------------------
# validation time:  22.313895225524902
# training time:  0.6839163303375244
# [950/2000] Train loss: 0.18931, Valid loss: 0.23093, Elapsed_time: 415.03166
# Current_accuracy : 68.650, Current_norm_ED  : 0.9380
# Best_accuracy    : 72.025, Best_norm_ED     : 0.9434
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# demiculverin              | demiculverin              | 0.2669	True
# she-ass                   | she-ass                   | 0.7996	True
# --------------------------------------------------------------------------------
# validation time:  22.57854199409485
# training time:  5.452561855316162
# [1000/2000] Train loss: 0.17390, Valid loss: 0.20647, Elapsed_time: 443.06377
# Current_accuracy : 72.013, Current_norm_ED  : 0.9438
# Best_accuracy    : 72.025, Best_norm_ED     : 0.9438
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# christianite              | christianite              | 0.0725	True
# clericality               | dlericality               | 0.1849	False
# --------------------------------------------------------------------------------
# validation time:  22.704582691192627
# training time:  0.6494278907775879
# [1050/2000] Train loss: 0.14258, Valid loss: 0.19828, Elapsed_time: 466.41778
# Current_accuracy : 72.737, Current_norm_ED  : 0.9460
# Best_accuracy    : 72.737, Best_norm_ED     : 0.9460
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# chamfers                  | chamfers                  | 0.3656	True
# inflexibility             | inflexibility             | 0.0363	True
# --------------------------------------------------------------------------------
# validation time:  22.30652165412903
# training time:  0.6801567077636719
# [1100/2000] Train loss: 0.14052, Valid loss: 0.19056, Elapsed_time: 489.40446
# Current_accuracy : 73.350, Current_norm_ED  : 0.9481
# Best_accuracy    : 73.350, Best_norm_ED     : 0.9481
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# signalese                 | signalese                 | 0.3948	True
# troaking                  | troaking                  | 0.5552	True
# --------------------------------------------------------------------------------
# validation time:  22.331847667694092
# training time:  0.6667137145996094
# [1150/2000] Train loss: 0.14124, Valid loss: 0.18907, Elapsed_time: 512.40302
# Current_accuracy : 73.362, Current_norm_ED  : 0.9486
# Best_accuracy    : 73.362, Best_norm_ED     : 0.9486
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# indescribable             | indescribable             | 0.1755	True
# rabbithearted             | rabbithearted             | 0.3697	True
# --------------------------------------------------------------------------------
# validation time:  22.42717933654785
# training time:  0.7363910675048828
# [1200/2000] Train loss: 0.15444, Valid loss: 0.20736, Elapsed_time: 535.56659
# Current_accuracy : 69.725, Current_norm_ED  : 0.9404
# Best_accuracy    : 73.362, Best_norm_ED     : 0.9486
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# rudish                    | rudish                    | 0.7416	True
# rough-stone               | rough-stone               | 0.2691	True
# --------------------------------------------------------------------------------
# validation time:  22.146803855895996
# training time:  0.6817936897277832
# [1250/2000] Train loss: 0.14576, Valid loss: 0.18507, Elapsed_time: 558.39619
# Current_accuracy : 74.438, Current_norm_ED  : 0.9503
# Best_accuracy    : 74.438, Best_norm_ED     : 0.9503
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# tenderly                  | tenderly                  | 0.6673	True
# Franco-italian            | Franco-italian            | 0.1018	True
# --------------------------------------------------------------------------------
# validation time:  22.369290113449097
# training time:  0.6361494064331055
# [1300/2000] Train loss: 0.15401, Valid loss: 0.19609, Elapsed_time: 581.40162
# Current_accuracy : 72.838, Current_norm_ED  : 0.9472
# Best_accuracy    : 74.438, Best_norm_ED     : 0.9503
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# toisech                   | toisech                   | 0.8844	True
# deterged                  | deterged                  | 0.5604	True
# --------------------------------------------------------------------------------
# validation time:  22.45267391204834
# training time:  0.7162785530090332
# [1350/2000] Train loss: 0.12283, Valid loss: 0.17557, Elapsed_time: 604.57058
# Current_accuracy : 74.725, Current_norm_ED  : 0.9513
# Best_accuracy    : 74.725, Best_norm_ED     : 0.9513
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# distort                   | distort                   | 0.2269	True
# Chaunce                   | Chaunce                   | 0.4930	True
# --------------------------------------------------------------------------------
# validation time:  22.23091197013855
# training time:  0.7380719184875488
# [1400/2000] Train loss: 0.14853, Valid loss: 0.18676, Elapsed_time: 627.53956
# Current_accuracy : 74.675, Current_norm_ED  : 0.9514
# Best_accuracy    : 74.725, Best_norm_ED     : 0.9514
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# cats-tail                 | cats-tail                 | 0.3957	True
# monetization              | wonetization              | 0.0718	False
# --------------------------------------------------------------------------------
# validation time:  22.479168176651
# training time:  0.7276294231414795
# [1450/2000] Train loss: 0.13157, Valid loss: 0.18142, Elapsed_time: 650.74636
# Current_accuracy : 73.812, Current_norm_ED  : 0.9491
# Best_accuracy    : 74.725, Best_norm_ED     : 0.9514
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# uninterchangeable         | uninterchangeable         | 0.3296	True
# implicity                 | ipiciy                    | 0.0814	False
# --------------------------------------------------------------------------------
# validation time:  22.1881320476532
# training time:  0.6309092044830322
# [1500/2000] Train loss: 0.12960, Valid loss: 0.19585, Elapsed_time: 673.56540
# Current_accuracy : 73.062, Current_norm_ED  : 0.9479
# Best_accuracy    : 74.725, Best_norm_ED     : 0.9514
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# wavefronts                | wavefronts                | 0.3772	True
# wire-bound                | cuire-bound               | 0.0964	False
# --------------------------------------------------------------------------------
# validation time:  22.42198610305786
# training time:  0.7398972511291504
# [1550/2000] Train loss: 0.13047, Valid loss: 0.18860, Elapsed_time: 696.72728
# Current_accuracy : 73.925, Current_norm_ED  : 0.9508
# Best_accuracy    : 74.725, Best_norm_ED     : 0.9514
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# brakesman                 | brakesman                 | 0.7818	True
# manometrical              | manometrical              | 0.4879	True
# --------------------------------------------------------------------------------
# validation time:  22.37533140182495
# training time:  0.6488254070281982
# [1600/2000] Train loss: 0.14078, Valid loss: 0.18434, Elapsed_time: 719.75144
# Current_accuracy : 73.600, Current_norm_ED  : 0.9486
# Best_accuracy    : 74.725, Best_norm_ED     : 0.9514
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# bashlyks                  | bashlyks                  | 0.4874	True
# squegging                 | squegging                 | 0.4841	True
# --------------------------------------------------------------------------------
# validation time:  22.03281807899475
# training time:  0.7332496643066406
# [1650/2000] Train loss: 0.13050, Valid loss: 0.17339, Elapsed_time: 742.51751
# Current_accuracy : 74.850, Current_norm_ED  : 0.9521
# Best_accuracy    : 74.850, Best_norm_ED     : 0.9521
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# prospice                  | prospice                  | 0.7846	True
# Risorgimento              | Risorgimento              | 0.1578	True
# --------------------------------------------------------------------------------
# validation time:  22.23313546180725
# training time:  0.7492032051086426
# [1700/2000] Train loss: 0.12913, Valid loss: 0.18208, Elapsed_time: 765.49985
# Current_accuracy : 74.213, Current_norm_ED  : 0.9512
# Best_accuracy    : 74.850, Best_norm_ED     : 0.9521
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# cachinnate                | cachinnate                | 0.5026	True
# paraffin                  | paraffin                  | 0.5454	True
# --------------------------------------------------------------------------------
# validation time:  22.34224843978882
# training time:  0.681084156036377
# [1750/2000] Train loss: 0.12622, Valid loss: 0.17196, Elapsed_time: 788.52318
# Current_accuracy : 75.538, Current_norm_ED  : 0.9531
# Best_accuracy    : 75.538, Best_norm_ED     : 0.9531
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# nonattributive            | nonattributie             | 0.0275	False
# slews                     | slews                     | 0.6736	True
# --------------------------------------------------------------------------------
# validation time:  22.232444047927856
# training time:  0.7299110889434814
# [1800/2000] Train loss: 0.14449, Valid loss: 0.18272, Elapsed_time: 811.48553
# Current_accuracy : 74.300, Current_norm_ED  : 0.9521
# Best_accuracy    : 75.538, Best_norm_ED     : 0.9531
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# howadji                   | howacli                   | 0.0605	False
# consciously               | consciously               | 0.5938	True
# --------------------------------------------------------------------------------
# validation time:  22.450074911117554
# training time:  0.7655215263366699
# [1850/2000] Train loss: 0.12341, Valid loss: 0.17130, Elapsed_time: 834.70113
# Current_accuracy : 75.950, Current_norm_ED  : 0.9550
# Best_accuracy    : 75.950, Best_norm_ED     : 0.9550
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Klagshamn                 | Klagshamn                 | 0.1785	True
# Petromyzonidae            | Petromyzonidae            | 0.1300	True
# --------------------------------------------------------------------------------
# validation time:  22.30524706840515
# training time:  0.6942539215087891
# [1900/2000] Train loss: 0.14608, Valid loss: 0.17325, Elapsed_time: 857.70063
# Current_accuracy : 74.963, Current_norm_ED  : 0.9518
# Best_accuracy    : 75.950, Best_norm_ED     : 0.9550
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# letdowns                  | letdowns                  | 0.5942	True
# curatorship               | curatorship               | 0.0631	True
# --------------------------------------------------------------------------------
# validation time:  22.271641731262207
# training time:  0.7187297344207764
# [1950/2000] Train loss: 0.13622, Valid loss: 0.17977, Elapsed_time: 880.69100
# Current_accuracy : 74.787, Current_norm_ED  : 0.9498
# Best_accuracy    : 75.950, Best_norm_ED     : 0.9550
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# metataxis                 | metataxis                 | 0.5450	True
# heehawed                  | heehawed                  | 0.2258	True
# --------------------------------------------------------------------------------
# validation time:  22.284797191619873
# training time:  5.5834691524505615
# [2000/2000] Train loss: 0.14186, Valid loss: 0.16044, Elapsed_time: 908.55927
# Current_accuracy : 76.700, Current_norm_ED  : 0.9565
# Best_accuracy    : 76.700, Best_norm_ED     : 0.9565
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Helioporidae              | Hlelioporidae             | 0.3454	False
# extra-articular           | exra-anticular            | 0.0734	False
# --------------------------------------------------------------------------------
# validation time:  22.03534960746765
# end the training
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\julia\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:3585: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
